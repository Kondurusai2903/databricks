# %%
# %%sql
#
# create catalog IF NOT EXISTS localpycharm
# MANAGED LOCATION 'abfss://localpycharm@dbstorageacc123.dfs.core.windows.net';

# %%
# %%sql
#
# create schema IF NOT EXISTS localpycharm.localpycharmschema;

# %%
# %%sql
# create schema if not exists databricks_course_ws.g3;
