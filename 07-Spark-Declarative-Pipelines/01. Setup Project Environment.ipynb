# %%
# %sql
CREATE CATALOG IF NOT EXISTS circuitbox
MANAGED LOCATION 'abfss://circuitbox@dbstorageacc123.dfs.core.windows.net'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS circuitbox.landing
MANAGED LOCATION 'abfss://circuitbox@dbstorageacc123.dfs.core.windows.net/landing'
COMMENT 'This is the landing zone for circuitbox';

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS circuitbox.lakehouse
MANAGED LOCATION 'abfss://circuitbox@dbstorageacc123.dfs.core.windows.net/lakehouse'
COMMENT 'This is the lakehouse Schema for circuitbox';

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS circuitbox.landing.operational_data
LOCATION 'abfss://circuitbox@dbstorageacc123.dfs.core.windows.net/landing/operational_data'
COMMENT 'This is the landing Volume for circuitbox';

# %%
# %fs ls 'abfss://circuitbox@dbstorageacc123.dfs.core.windows.net'

# %%
# %sql
# -- show catalogs
# -- show schemas in circuitbox
# -- show tables in circuitbox.landing;

# -- DESC CATALOG EXTENDED circuitbox;
# -- DESC SCHEMA EXTENDED circuitbox.landing;
# -- DESC SCHEMA EXTENDED circuitbox.lakehouse;

# %fs ls /Volumes/circuitbox/landing/operational_data/orders/

# %%
# dbutils.widgets.text('catalog','transportation')

# %%
catalog = dbutils.widgets.get("catalog")

# spark.sql(f"CREATE CATALOG IF NOT EXISTS `{catalog}`")
# spark.sql(f"CREATE SCHEMA IF NOT EXISTS `{catalog}`.`bronze`")
# spark.sql(f"CREATE SCHEMA IF NOT EXISTS `{catalog}`.`silver`")
# spark.sql(f"CREATE SCHEMA IF NOT EXISTS `{catalog}`.`gold`")

# %%
# %sql
create catalog if not exists transportation
managed location 'abfss://project-transportation@dbstorageacc123.dfs.core.windows.net/';

create schema if not exists transportation.bronze;
create schema if not exists transportation.silver;
create schema if not exists transportation.gold;
