# %% [markdown]
# ## Configure Access to cloud storage via unity catalog

# %% [markdown]
# Access cloud storage

# %%
# %fs ls

# %%
# %fs ls 'abfss://demo@dbstorageacc123.dfs.core.windows.net'

# %%
# %sql
CREATE EXTERNAL LOCATION IF NOT EXISTS dbstorageacc123demo
URL 'abfss://demo@dbstorageacc123.dfs.core.windows.net'
WITH (STORAGE CREDENTIAL `dbstorageacc123`)
COMMENT 'External location for dbstorageacc123'
