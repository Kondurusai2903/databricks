# %%
# %sql
create catalog if not exists gtesting
managed location 'abfss://gtesting@dbstorageacc123.dfs.core.windows.net'
comment 'this is for testing lakehouse'

# %%
# %sql
use catalog gtesting;

create schema if not exists learning
managed location 'abfss://gtesting@dbstorageacc123.dfs.core.windows.net/learning'
comment 'this is for testing lakehouse'

# %%
dbutils.fs.put('abfss://gtesting@dbstorageacc123.dfs.core.windows.net/learning/hello.txt','This is learning course for the databricks lakehouse')

# %%
# %sql
DESCRIBE SCHEMA EXTENDED gtesting.learning;

# %%
# %sql
DESCRIBE CATALOG EXTENDED gtesting
