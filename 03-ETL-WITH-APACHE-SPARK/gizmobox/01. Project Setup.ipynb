# %% [markdown]
# ## Set-up the Project environment for Gizmobox Data Lakehouse

# %%
# %fs ls 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net'

# %%
# %fs ls 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/landing/'

# %%
# %sql
show catalogs;

# %%
# %sql
CREATE CATALOG IF NOT EXISTS GIZMOBOX
MANAGED LOCATION 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net'
COMMENT 'This is the catalog for the GizmoBox Data Lakehouse'

# %% [markdown]
# ### Create schemas
#
# - Landing
# - Bronze
# - Silver
# - Gold

# %%
# %sql
select current_catalog();

# %%
# %sql
use catalog gizmobox;

# %%
# %sql
select current_catalog();

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS landing
MANAGED LOCATION 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/landing';

CREATE SCHEMA IF NOT EXISTS bronze
MANAGED LOCATION 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/bronze';

CREATE SCHEMA IF NOT EXISTS silver
MANAGED LOCATION 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/silver';

CREATE SCHEMA IF NOT EXISTS gold
MANAGED LOCATION 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/gold'

# %%
# %sql
show schemas;

# %% [markdown]
# ## Create Volumne

# %%
# %sql
use catalog gizmobox;
use schema landing;


CREATE EXTERNAL VOLUME IF NOT EXISTS operational_data
LOCATION 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/landing/operational-data'
COMMENT 'This is the volume for the GizmoBox Data Lakehouse'

# %%
# %fs ls /Volumes/gizmobox/landing/operational_data

# %%
# %fs ls /Volumes/gizmobox/landing/operational_data/addresses

# %%
# %sql
create catalog if not exists gizmobox1;

# %%
# %sql
use catalog gizmobox;


create schema if not exists landing1
managed location 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/landing1'

# %%
# %sql
SHOW SCHEMAS IN gizmobox;

# %%
# %sql
DESCRIBE SCHEMA EXTENDED gizmobox.landing1;

# %%
# %sql
DESCRIBE SCHEMA EXTENDED gizmobox.landing;

# %%
# %sql
use catalog gizmobox;

use schema landing1;

create external volume if not exists testing_data
location 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/landing1/testing-data'

# %%
# %python
dbutils.fs.put("/Volumes/gizmobox/landing1/testing_data/hello.txt", "hello gizmobox")

# %%
dbutils.fs.rm("/Volumes/gizmobox/landing1/testing_data/hello.txt")

# %%
dbutils.fs.rm("/Volumes/gizmobox/landing1/testing_data")

# %%
# %sql
DROP SCHEMA gizmobox.landing1 CASCADE;

# %%
# %sql
SHOW SCHEMAS IN gizmobox;

# %%
# %sql
SHOW SCHEMAS LIKE 'landing1';

# %%
# %sql
CREATE VOLUME IF NOT EXISTS gizmobox.bronze.test_volume
COMMENT 'Test volume to verify ADLS folder creation';

# %%
# %python
dbutils.fs.put("/Volumes/gizmobox/bronze/test_volume/hello.txt", "hello from bronze schema")

# %%
# %sql
DESCRIBE SCHEMA gizmobox.landing

# %%
# %sql
DESCRIBE SCHEMA extended gizmobox.bronze

# %%
# %sql
show schemas in gizmobox

# %%
# %sql
-- First
CREATE CATALOG IF NOT EXISTS retailhub
MANAGED LOCATION 'abfss://retailhub@storageacc99.dfs.core.windows.net/'
COMMENT 'Retail Hub Lakehouse';


-- Second 
CREATE SCHEMA IF NOT EXISTS gizmobox.staging
MANAGED LOCATION 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/staging';


-- Third 
CREATE EXTERNAL VOLUME IF NOT EXISTS gizmobox.external_data.payments_vol
LOCATION 'abfss://gizmobox@dbstorageacc123.dfs.core.windows.net/external-data/payments/'
COMMENT 'External volume for data files';

# %%
# %sql
-- fourth 
show schemas in gizmobox;
-- fifth one 
DROP SCHEMA gizmobox.staging CASCADE;
