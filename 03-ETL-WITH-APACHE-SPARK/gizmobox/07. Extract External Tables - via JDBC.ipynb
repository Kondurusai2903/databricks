# %% [markdown]
# ### Extract Data from the External SQL Table
#
# - create a Bronze schema in Hive_metastore
# - Create external Table

# %% [markdown]
# #### 1.Create a Bronze Schema in Hive_metastore

# %%
# Show database connection strings
# %sql

CREATE TABLE IF NOT EXISTS gizmobox.bronze.refunds;

# USING JDBC
# OPTIONS (
#   url 'jdbc:sqlserver://gizmobox-863.database.windows.net:1433;database=gizmobox-db',
#   dbtable 'refunds',
#   user 'gizmoboxadmin',
#   password 'Sai@2903'
# )

# %%
# %sql
-- CREATE TABLE IF NOT EXISTS gizmobox.bronze.refunds
-- USING JDBC
-- OPTIONS (
--     url 'jdbc:sqlserver://gizmobox-863.database.windows.net:1433;database=gizmobox-db',
--     dbtable 'refunds',
--     user 'gizmoboxadmin',
--     password 'Sai@2903'
-- )

# %%
# %sql
select * from gizmobox.bronze.refunds;

# %% [markdown]
# #### 2. Create External Table

# %%
# %sql
select * from gizmobox.bronze.refunds;

# %%
# %sql
DROP TABLE IF EXISTS gizmobox.bronze.refunds;
