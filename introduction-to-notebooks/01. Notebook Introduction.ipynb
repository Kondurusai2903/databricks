# %% [markdown]
# # Introduction to Notebooks
#
# The notebook give you an introduction to databricks

# %%
print('hello python')

# %%
name = 'konduru sai'
print(f"My name is {name}")

# %%
# %sql
with sequence1 as (
  select 1 as value
  union all
  select value + 1
  from sequence1
  where value < 20
)

select repeat("*",20-value+1) as value from sequence1
